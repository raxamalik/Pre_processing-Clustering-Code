# %%
import os
folderpath = r"C:\Users\Raza Awan\Pictures\wiki-en_000002.txt"
filepaths = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]
input_files = []
for path in filepaths:
    with open(path, 'r', encoding = "ISO-8859-1") as f:
        file = f.readlines()
        input_files.append(file)

# %%
input_files
# Out:
# [['[[Afonso VI of Portugal]]\n',
#   '\n',
#   ' \n',
#   '\n',
#   'Afonso VI (; English: Alphonzo or Alphonse, Old Portuguese: Affonso; 21 August 1643 â\x80\x93 12 September 1683) was King of Portugal and the Algarves, the second of the House of Braganza, known as "the Victorious" ().\n',
#   '\n',
#   '== Early life ==\n',
#   'At the age of three, Afonso suffered an illness that left him paralyzed on the left side of his body, as well as leaving him mentally unstable. His father created him 10th Duke of Braganza.\n',
#   '\n',
#   'After the 1653 death of his eldest brother TeodÃ³sio, Prince of Brazil, Afonso became the heir-apparent to the throne of the kingdom. He received also the crown-princely title 2nd Prince of Brazil.\n',
#   '\n',
#   '== Succession ==\n',
#   'Portrait of Infante Afonso; JosÃ© de Avelar Rebelo, 1653.\n',
# ...

# %%
sizeOfmyfiles = len(input_files)
print(sizeOfmyfiles)
# Out:
# 1

# %%
listToString =' '.join(map(str, input_files))

# %%
listToString
# Out:
# '[\'[[Afonso VI of Portugal]]\\n\', \'\\n\', \' \\n\', \'\\n\', \'Afonso VI (; English: Alphonzo or Alphonse, Old Portuguese: Affonso; 21 August 1643 â\\x80\\x93 12 September 1683) was King of Portugal and the Algarves, the second of the House of Braganza, known as "the Victorious" ().\\n\', \'\\n\', \'== Early life ==\\n\', \'At the age of three, Afonso suffered an illness that left him paralyzed on the left side of his body, as well as leaving him mentally unstable. His father created him 10th Duke of Braganza.\\n\', \'\\n\', \'After the 1653 death of his eldest brother TeodÃ³sio, Prince of Brazil, Afonso became the heir-apparent to the throne of the kingdom. He received also the crown-princely title 2nd Prince of Brazil.\\n\', \'\\n\', \'== Succession ==\\n\', \'Portrait of Infante Afonso; JosÃ© de Avelar Rebelo, 1653.\\n\', "He succeeded his father (JoÃ£o IV) in 1656 at the age of thirteen. His mother, Luisa of Medina-Sidonia, was named regent in his father\'s will. His mental in
# ...

# %%
import nltk
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Raza
# [nltk_data]     Awan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Raza
# [nltk_data]     Awan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
listToString
# Out:
# '[\'[[Afonso VI of Portugal]]\\n\', \'\\n\', \' \\n\', \'\\n\', \'Afonso VI (; English: Alphonzo or Alphonse, Old Portuguese: Affonso; 21 August 1643 â\\x80\\x93 12 September 1683) was King of Portugal and the Algarves, the second of the House of Braganza, known as "the Victorious" ().\\n\', \'\\n\', \'== Early life ==\\n\', \'At the age of three, Afonso suffered an illness that left him paralyzed on the left side of his body, as well as leaving him mentally unstable. His father created him 10th Duke of Braganza.\\n\', \'\\n\', \'After the 1653 death of his eldest brother TeodÃ³sio, Prince of Brazil, Afonso became the heir-apparent to the throne of the kingdom. He received also the crown-princely title 2nd Prince of Brazil.\\n\', \'\\n\', \'== Succession ==\\n\', \'Portrait of Infante Afonso; JosÃ© de Avelar Rebelo, 1653.\\n\', "He succeeded his father (JoÃ£o IV) in 1656 at the age of thirteen. His mother, Luisa of Medina-Sidonia, was named regent in his father\'s will. His mental in
# ...

# %%
from nltk.tokenize import word_tokenize
text = word_tokenize(listToString)

# %%
data = [word for word in text if not word in stopwords.words()]
print(data)
# Out:
# ['[', "'", '[', '[', 'Afonso', 'VI', 'Portugal', ']', ']', '\\n', "'", ',', "'\\n", "'", ',', "'", '\\n', "'", ',', "'\\n", "'", ',', "'Afonso", 'VI', '(', ';', 'English', ':', 'Alphonzo', 'Alphonse', ',', 'Old', 'Portuguese', ':', 'Affonso', ';', '21', 'August', '1643', 'â\\x80\\x93', '12', 'September', '1683', ')', 'King', 'Portugal', 'Algarves', ',', 'second', 'House', 'Braganza', ',', 'known', '``', 'Victorious', "''", '(', ')', '.\\n', "'", ',', "'\\n", "'", ',', "'==", 'Early', 'life', '==\\n', "'", ',', "'At", 'age', 'three', ',', 'Afonso', 'suffered', 'illness', 'left', 'paralyzed', 'left', 'side', 'body', ',', 'well', 'leaving', 'mentally', 'unstable', '.', 'His', 'father', 'created', '10th', 'Duke', 'Braganza.\\n', "'", ',', "'\\n", "'", ',', "'After", '1653', 'death', 'eldest', 'brother', 'TeodÃ³sio', ',', 'Prince', 'Brazil', ',', 'Afonso', 'became', 'heir-apparent', 'throne', 'kingdom', '.', 'He', 'received', 'crown-princely', 'title', '2nd', 'Prince', 'Brazil.\\n', "'", 
# ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Raza
# [nltk_data]     Awan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemma = WordNetLemmatizer()

# %%
lem = []

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to C:\Users\Raza
# [nltk_data]     Awan\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
for r in data:
    lem.append(lemma.lemmatize(r))

# %%
print(lemma.lemmatize('town'))
# Out:
# town

# %%
import re
dataupdate = []
dataupdate = [re.sub('[^a-zA-Z0-9]', '', _) for _ in lem]
dataupdate
# Out:
# ['',
#  '',
#  '',
#  '',
#  'Afonso',
#  'VI',
#  'Portugal',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'Afonso',
#  'VI',
#  '',
#  '',
#  'English',
#  '',
#  'Alphonzo',
#  'Alphonse',
#  '',
#  'Old',
#  'Portuguese',
#  '',
#  'Affonso',
#  '',
#  '21',
#  'August',
#  '1643',
#  'x80x93',
#  '12',
#  'September',
#  '1683',
#  '',
#  'King',
#  'Portugal',
#  'Algarves',
#  '',
#  'second',
#  'House',
#  'Braganza',
#  '',
#  'known',
#  '',
#  'Victorious',
#  '',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  '',
#  'Early',
#  'life',
#  'n',
#  '',
#  '',
#  'At',
#  'age',
#  'three',
#  '',
#  'Afonso',
#  'suffered',
#  'illness',
#  'left',
#  'paralyzed',
#  'left',
#  'side',
#  'body',
#  '',
#  'well',
#  'leaving',
#  'mentally',
#  'unstable',
#  '',
#  'His',
#  'father',
#  'created',
#  '10th',
#  'Duke',
#  'Braganzan',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'After',
# ...

# %%
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
#import warnings filter
from warnings import simplefilter
#ignore all future warnings
simplefilter(action = 'ignore', category = FutureWarning)

# %%
vectorizer = TfidfVectorizer(stop_words = 'english')
X = vectorizer.fit_transform(dataupdate)

# %%
cluster = 3
model = KMeans(n_clusters = cluster, init = 'k-means++', max_iter = 100, n_init = 1)
model.fit(X)
# Out:
# KMeans(max_iter=100, n_clusters=3, n_init=1)

# %%
print("Top terms per cluster: ")
order_centroids = model.cluster_centers_.argsort()[:, :: -1]
terms = vectorizer.get_feature_names()
# Out:
# Top terms per cluster:

# %%
for i in range(cluster):
    print("Cluster %d : " % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
# Out:
# Cluster 0 :
#  alfonso
#  king
#  ii
#  married
#  x80x93
#  wittig
#  spanish
#  asturias
#  afonso
#  xii
# Cluster 1 :
#  spain
#  crnica
#  court
#  cousin
#  created
#  creation
#  crisis
#  cristina
#  crownprincely
#  country
# Cluster 2 :
#  military
#  yves
#  crownprincely
#  cousin
#  created
#  creation
#  crisis
#  cristina
#  crnica
#  cuba

# %%
Y = vectorizer.transform(["age"])
guessing = model.predict(Y)
print(guessing)
# Out:
# [0]

# %%
Y = vectorizer.transform(["country"])
guessing = model.predict(Y)
print(guessing)
# Out:
# [0]
